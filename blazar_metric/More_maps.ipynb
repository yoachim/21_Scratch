# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.plots as plots
import pandas as pd

# %%
# conenct to the simulation database
dbFile = 'baseline_nexp2_v1.7_10yrs.db'
runName = dbFile.replace('.db', '')
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
for filtername in 'ugrizy':
    sql = 'filter="%s"' % filtername
    # Let's plug in the magnitudes for one type
    metric = metrics.MedianMetric(col='seeingFwhmEff')
    slicer = slicers.HealpixSlicer()

    summaryMetrics=[metrics.MeanMetric(maskVal=0)]
    plotDict = {'colorMax': 1.75}
    #plotFuncs = [plots.HealpixSkyMap()]
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict,
                                                 summaryMetrics=summaryMetrics,
                                                 runName=runName))
    plotDict = {}
    metric = metrics.MedianMetric(col='saturation_mag')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict,
                                                 summaryMetrics=summaryMetrics,
                                                 runName=runName))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bgroup = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bgroup.runAll()
bgroup.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint filter="u" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 130925 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_u_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_u_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 452001 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_r_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 397742 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_z_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 205011 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_g_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 404071 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_y_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_y_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" for columns ['fieldDec', 'visitExposureTime', 'skyBrightness', 'fieldRA', 'numExposures', 'filter', 'seeingFwhmEff', 'airmass']
# Found 455743 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_Median_seeingFwhmEff_i_HEAL', 'baseline_nexp2_v1_7_10yrs_Median_saturation_mag_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 452 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 1.15105  dipole: lon: -70.6468, lat: -0.763587, amp: 0.135241
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 281 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 13.0333  dipole: lon: 109.958, lat: 6.46188, amp: 0.271175
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 593 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 1.08861  dipole: lon: -55.6268, lat: 55.454, amp: 0.131175
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 324 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 14.3188  dipole: lon: 126.403, lat: -57.7908, amp: 0.279247
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="z"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 515 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 1.03679  dipole: lon: -55.1326, lat: 63.7441, amp: 0.164289
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 291 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 13.7658  dipole: lon: 126.207, lat: -63.5836, amp: 0.342535
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="g"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 555 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:226: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 1.14049  dipole: lon: -65.5476, lat: 54.9858, amp: 0.126533
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 324 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 14.4191  dipole: lon: 117.953, lat: -60.0261, amp: 0.271343
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="y"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 698 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 0.951731  dipole: lon: -60.9333, lat: 10.2084, amp: 0.101868
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 363 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 13.1484  dipole: lon: 119.12, lat: -7.68509, amp: 0.231348
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="i"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 593 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 1.06023  dipole: lon: -57.3793, lat: 62.7536, amp: 0.161111
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 345 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 14.1061  dipole: lon: 123.946, lat: -63.6121, amp: 0.331405
#   warnings.warn(
# Plotting complete.
