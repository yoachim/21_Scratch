# %%
import numpy as np
from lsst.sims.featureScheduler.modelObservatory import Model_observatory

# %%
mo = Model_observatory()

# %%
print(mo.downtimes)
# Out:
# [(59608.66, 59609.66) (59613.66, 59616.66) (59640.66, 59647.66)
#  (59671.66, 59672.66) (59676.66, 59677.66) (59693.66, 59694.66)
#  (59734.66, 59735.66) (59737.66, 59744.66) (59796.66, 59797.66)
#  (59844.66, 59851.66) (59871.66, 59872.66) (59886.66, 59893.66)
#  (59938.66, 59941.66) (59995.66, 59996.66) (60102.66, 60109.66)
#  (60143.66, 60144.66) (60156.66, 60157.66) (60166.66, 60167.66)
#  (60251.66, 60258.66) (60362.66, 60363.66) (60435.66, 60438.66)
#  (60439.66, 60440.66) (60467.66, 60481.66) (60530.66, 60531.66)
#  (60567.66, 60568.66) (60580.66, 60581.66) (60634.66, 60637.66)
#  (60652.66, 60655.66) (60676.66, 60677.66) (60766.66, 60767.66)
#  (60772.66, 60773.66) (60783.66, 60786.66) (60832.66, 60839.66)
#  (60840.66, 60847.66) (60903.66, 60904.66) (60940.66, 60941.66)
#  (60981.66, 60988.66) (61025.66, 61028.66) (61078.66, 61079.66)
#  (61088.66, 61089.66) (61110.66, 61111.66) (61150.66, 61151.66)
#  (61197.66, 61211.66) (61298.66, 61299.66) (61338.66, 61339.66)
# ...

# %%
# The default starting MJD
print(mo.mjd)
# Out:
# 59853.98383868858
