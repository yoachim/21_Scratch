# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'baseline_nexp2_v1.7_10yrs.db'
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql = 'filter="r"'
metric = metrics.Coaddm5Metric()
slicer = slicers.HealpixSlicer()
summaryStats = []
plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
# %%time 
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" for columns ['fieldRA', 'fieldDec', 'fiveSigmaDepth']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 47.9 s, sys: 827 ms, total: 48.7 s
# Wall time: 54.6 s

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 218 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 26.4792  dipole: lon: 110.137, lat: -70.9847, amp: 0.430174
#   mono, lon, lat, amp
# Plotting complete.

# %%
bundleList = []
sql = 'filter="r"'
metric = metric = metrics.Coaddm5Metric()
slicer = slicers.HealpixSlicer(useCamera=True, useCache=False)
summaryStats = []
plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
# %%time 
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" for columns ['fiveSigmaDepth', 'fieldDec', 'rotSkyPos', 'observationStartMJD', 'fieldRA']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/git_repos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py in runAll(self, clearMemory, plotNow, plotKwargs)
#     241             #  constraint.
#     242             self.runCurrent(constraint, clearMemory=clearMemory,
# --> 243                             plotNow=plotNow, plotKwargs=plotKwargs)
#     244
#     245     def setCurrent(self, constraint):
#
# ~/git_repos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py in runCurrent(self, constraint, simData, clearMemory, plotNow, plotKwargs)
#     321             if self.verbose:
#     322                 print('Running: ', compatibleList)
# --> 323             self._runCompatible(compatibleList)
#     324             if self.verbose:
#     325                 print('Completed metric generation.')
#
# ~/git_repos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py in _runCompatible(self, compatibleList)
#     436             slicer.setupSlicer(self.simData, self.fieldData, maps=uniqMaps)
#     437         else:
# --> 438             slicer.setupSlicer(self.simData, maps=uniqMaps)
#     439         # Copy the slicer (after setup) back into the individual metricBundles.
#     440         if slicer.slicerName != 'HealpixSlicer' or slicer.slicerName != 'UniSlicer':
#
# ~/git_repos/sims_maf/python/lsst/sims/maf/slicers/baseSpatialSlicer.py in setupSlicer(self, simData, maps)
#     114         if self.useCamera:
#     115             self._setupLSSTCamera()
# --> 116             self._presliceFootprint(simData)
#     117         else:
#     118             if self.latLonDeg:
#
# ~/git_repos/sims_maf/python/lsst/sims/maf/slicers/baseSpatialSlicer.py in _presliceFootprint(self, simData)
#     190                                                self.slicePoints['dec'][hpIndices],
#     191                                                epoch=self.epoch,
# --> 192                                                camera=self.camera, obs_metadata=obs_metadata)
#     193                 if self.scienceChips:
#     194                     # I think it's W for wavefront sensor
#
# ~/git_repos/sims_coordUtils/python/lsst/sims/coordUtils/CameraUtils.py in _chipNameFromRaDec(ra, dec, pm_ra, pm_dec, parallax, v_rad, obs_metadata, camera, epoch, allow_multiple_chips)
#     317                                    obs_metadata=obs_metadata, epoch=epoch)
#     318
# --> 319     ans = chipNameFromPupilCoords(xp, yp, camera=camera, allow_multiple_chips=allow_multiple_chips)
#     320
#     321     return ans
#
# ~/git_repos/sims_coordUtils/python/lsst/sims/coordUtils/CameraUtils.py in chipNameFromPupilCoords(xPupil, yPupil, camera, allow_multiple_chips)
#     356         pupilPointList = [geom.Point2D(xPupil, yPupil)]
#     357
# --> 358     detList = camera.findDetectorsList(pupilPointList, FIELD_ANGLE)
#     359
#     360     for pt, det in zip(pupilPointList, detList):
#
# KeyboardInterrupt:

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# Plotting complete.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:538: UserWarning: MetricBundle (opsim_CoaddM5_r_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
