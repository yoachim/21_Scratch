# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'baseline_nexp2_v1.7_10yrs.db'
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql = 'filter="r"'
metric = metrics.Coaddm5Metric()
slicer = slicers.HealpixSlicer()
summaryStats = []
plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
# %%time 
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" for columns ['fieldRA', 'fieldDec', 'fiveSigmaDepth']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 37.5 s, sys: 369 ms, total: 37.9 s
# Wall time: 37.9 s

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 218 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 26.4792  dipole: lon: 110.137, lat: -70.9847, amp: 0.430174
#   mono, lon, lat, amp
# Plotting complete.

# %%
bundleList = []
sql = 'filter="r"'
metric = metric = metrics.Coaddm5Metric()
slicer = slicers.HealpixSlicer(useCamera=False, useCache=False)
summaryStats = []
plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
# %%time 
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" for columns ['fieldRA', 'fieldDec', 'fiveSigmaDepth']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 25.3 s, sys: 407 ms, total: 25.7 s
# Wall time: 25.2 s

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 218 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 26.4792  dipole: lon: 110.137, lat: -70.9847, amp: 0.430174
#   mono, lon, lat, amp
# Plotting complete.

# %%
bundleList = []
sql = 'filter="r"'
metric = metric = metrics.Coaddm5Metric()
slicer = slicers.HealpixSlicer(useCamera=True, useCache=False)
summaryStats = []
plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
# %%time 
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="r" for columns ['observationStartMJD', 'rotSkyPos', 'fieldRA', 'fieldDec', 'fiveSigmaDepth']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 2h 34min 42s, sys: 4.96 s, total: 2h 34min 47s
# Wall time: 2h 34min 47s

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 232 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 26.4188  dipole: lon: 110.349, lat: -70.9146, amp: 0.428076
#   mono, lon, lat, amp
# Plotting complete.
