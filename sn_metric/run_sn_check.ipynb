# %%
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import sqlite3
import numpy as np
from lsst.sims.maf.metrics.snNSNMetric import SNNSNMetric
import healpy as hp
# %matplotlib inline
import glob

# %%
dbfiles = glob.glob('*10yrs.db')
dbfiles.sort()

# %%
nside = 4
sql = ''
# what is this zlim thingy?
#metric = SNNSNMetric( verbose=False, zlim_coeff=0.98)
metric = SNNSNMetric( verbose=False)
result_list = []
for filename in dbfiles:
    opsimdb = db.OpsimDatabase(filename)
    runname = filename.replace('_10yrs.db', '')
    bundleList = []
    slicer = slicers.HealpixSlicer(nside=nside)
    resultsDb = db.ResultsDb(outDir=runname)
    summaryStats = [metrics.MeanMetric(), metrics.MedianMetric(), metrics.SumMetric()]

    bundleList.append(metricBundles.MetricBundle(metric, slicer,sql,runName=runname, summaryMetrics=summaryStats))
    outDir = runname
    resultsDb = db.ResultsDb(outDir=outDir)
    bundleDict = metricBundles.makeBundlesDictFromList(bundleList)
    bgroup = metricBundles.MetricBundleGroup(bundleDict, opsimdb, outDir=outDir, resultsDb=resultsDb)
    bgroup.runAll()
    bgroup.plotAll(closefigs=False)
    print(runname, bundleDict['SNNSNMetric_nSN'].summaryValues, bundleDict['SNNSNMetric_zlim'].summaryValues)
    result_list.append((runname, bundleDict['SNNSNMetric_nSN'].summaryValues, bundleDict['SNNSNMetric_zlim'].summaryValues))
# Out:
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 54522 699 78
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 63609 699 91
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 77589 699 111
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2044984 visits
# Running:  ['baseline_nexp2_v1_7_1_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 185.708  dipole: lon: 129.401, lat: -45.9532, amp: 196.028
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 0.0113362  dipole: lon: 118.817, lat: -25.611, amp: 0.120034
#   warnings.warn(
# Plotting complete.
# baseline_nexp2_v1.7.1 {'Mean': 240.59971428571427, 'Median': 242.306, 'Sum': 30315.564} {'Mean': 0.03650793650793651, 'Median': 0.25, 'Sum': 4.6000000000000005}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2045493 visits
# Running:  ['baseline_nexp2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 180.749  dipole: lon: 132.469, lat: -44.6324, amp: 172.672
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 0.0602844  dipole: lon: 115.027, lat: 53.9003, amp: 0.229297
#   warnings.warn(
# Plotting complete.
# baseline_nexp2_v1.7 {'Mean': 227.95896825396824, 'Median': 243.3515, 'Sum': 28722.829999999998} {'Mean': 0.010753968253968257, 'Median': 0.25, 'Sum': 1.3550000000000004}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2044963 visits
# Running:  ['footprint_6_v1_7_1_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 111.695  dipole: lon: 130.302, lat: -54.8298, amp: 150.038
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.0941293  dipole: lon: 75.7283, lat: -43.0573, amp: 0.330012
#   warnings.warn(
# Plotting complete.
# footprint_6_v1.7.1 {'Mean': 153.71603053435115, 'Median': 129.091, 'Sum': 20136.8} {'Mean': -0.00992366412213741, 'Median': 0.25, 'Sum': -1.3000000000000007}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2044854 visits
# Running:  ['rolling_fpw_scale0_2_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:226: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 130.455  dipole: lon: 141.475, lat: -43.3177, amp: 208.821
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.222044  dipole: lon: -174.405, lat: -85.9596, amp: 0.279065
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.2_nslice2_v1.7 {'Mean': 184.9656587301587, 'Median': 142.21800000000002, 'Sum': 23305.673} {'Mean': -0.13174603174603175, 'Median': 0.25, 'Sum': -16.6}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2045896 visits
# Running:  ['rolling_fpw_scale0_2_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 124.102  dipole: lon: 137.908, lat: -44.0099, amp: 194.284
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.155143  dipole: lon: 158.139, lat: -68.6147, amp: 0.190526
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.2_nslice3_v1.7 {'Mean': 175.91784920634922, 'Median': 145.50650000000002, 'Sum': 22165.649} {'Mean': -0.09543650793650794, 'Median': 0.25, 'Sum': -12.025}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2045625 visits
# Running:  ['rolling_fpw_scale0_4_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 126.473  dipole: lon: 130.939, lat: -50.5106, amp: 196.482
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.209758  dipole: lon: -179.941, lat: -74.9976, amp: 0.27348
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.4_nslice2_v1.7 {'Mean': 183.89488095238093, 'Median': 154.708, 'Sum': 23170.754999999997} {'Mean': -0.1242063492063492, 'Median': 0.25, 'Sum': -15.649999999999999}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2046516 visits
# Running:  ['rolling_fpw_scale0_4_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 119.375  dipole: lon: 135.316, lat: -45.2888, amp: 156.512
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.174216  dipole: lon: 27.4626, lat: -84.5568, amp: 0.206078
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.4_nslice3_v1.7 {'Mean': 162.13380952380953, 'Median': 140.822, 'Sum': 20428.86} {'Mean': -0.10654761904761906, 'Median': 0.25, 'Sum': -13.425}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2046375 visits
# Running:  ['rolling_fpw_scale0_6_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 120.212  dipole: lon: 131.172, lat: -51.3743, amp: 176.367
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.186561  dipole: lon: 141.218, lat: -86.4824, amp: 0.213704
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.6_nslice2_v1.7 {'Mean': 172.13835714285716, 'Median': 153.2615, 'Sum': 21689.433} {'Mean': -0.11646825396825397, 'Median': 0.25, 'Sum': -14.675}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2047591 visits
# Running:  ['rolling_fpw_scale0_6_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 108.005  dipole: lon: 135.777, lat: -49.8444, amp: 139.395
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.142538  dipole: lon: 161.475, lat: -67.0012, amp: 0.1738
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.6_nslice3_v1.7 {'Mean': 147.9835238095238, 'Median': 154.888, 'Sum': 18645.924} {'Mean': -0.08888888888888888, 'Median': 0.25, 'Sum': -11.2}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2047378 visits
# Running:  ['rolling_fpw_scale0_8_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 113.568  dipole: lon: 127.391, lat: -52.1534, amp: 169.8
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.184918  dipole: lon: -127.327, lat: -83.2494, amp: 0.217796
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.8_nslice2_v1.7 {'Mean': 164.33243650793654, 'Median': 150.36350000000002, 'Sum': 20705.887000000002} {'Mean': -0.11646825396825396, 'Median': 0.25, 'Sum': -14.674999999999999}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2048569 visits
# Running:  ['rolling_fpw_scale0_8_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 126.931  dipole: lon: 129.782, lat: -52.8919, amp: 105.726
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.184971  dipole: lon: -163.63, lat: -86.9941, amp: 0.217392
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.8_nslice3_v1.7 {'Mean': 158.57289682539684, 'Median': 167.3475, 'Sum': 19980.185} {'Mean': -0.11468253968253968, 'Median': 0.25, 'Sum': -14.45}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2047976 visits
# Running:  ['rolling_fpw_scale0_9_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 120.225  dipole: lon: 130.018, lat: -54.1102, amp: 170.342
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.192929  dipole: lon: -169.166, lat: -76.4671, amp: 0.238131
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.9_nslice2_v1.7 {'Mean': 171.69007142857143, 'Median': 170.8655, 'Sum': 21632.949} {'Mean': -0.11884920634920634, 'Median': 0.225, 'Sum': -14.975}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2049451 visits
# Running:  ['rolling_fpw_scale0_9_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 117.261  dipole: lon: 129.24, lat: -58.3745, amp: 110.503
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.20884  dipole: lon: -172.375, lat: -82.1226, amp: 0.257106
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale0.9_nslice3_v1.7 {'Mean': 151.73303968253967, 'Median': 176.0805, 'Sum': 19118.362999999998} {'Mean': -0.12658730158730155, 'Median': 0.225, 'Sum': -15.949999999999998}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2048598 visits
# Running:  ['rolling_fpw_scale1_0_nslice2_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 118.819  dipole: lon: 123.505, lat: -57.3084, amp: 162.396
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.208089  dipole: lon: -33.901, lat: -86.8273, amp: 0.254057
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale1.0_nslice2_v1.7 {'Mean': 169.63716666666667, 'Median': 167.8025, 'Sum': 21374.283} {'Mean': -0.1261904761904762, 'Median': 0.25, 'Sum': -15.9}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2050138 visits
# Running:  ['rolling_fpw_scale1_0_nslice3_v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 120.4  dipole: lon: 122.876, lat: -62.2345, amp: 122.052
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.133474  dipole: lon: -163.873, lat: -69.9414, amp: 0.157092
#   warnings.warn(
# Plotting complete.
# rolling_fpw_scale1.0_nslice3_v1.7 {'Mean': 159.69038888888886, 'Median': 179.2255, 'Sum': 20120.988999999998} {'Mean': -0.08710317460317461, 'Median': 0.25, 'Sum': -10.975000000000001}
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['visitExposureTime', 'fiveSigmaDepth', 'night', 'observationStartMJD', 'fieldRA', 'visitTime', 'filter', 'fieldDec', 'observationId', 'numExposures'].
# Found 2043258 visits
# Running:  ['six_stripe_scale0_90_nslice6_fpw0_9_nrw0_0v1_7_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 178.577  dipole: lon: 97.2106, lat: -65.2779, amp: 390.575
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: -0.0875713  dipole: lon: 174.717, lat: -72.1782, amp: 0.32542
#   warnings.warn(
# Plotting complete.
# six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7 {'Mean': 298.34863358778625, 'Median': 251.381, 'Sum': 39083.671} {'Mean': 0.008778625954198456, 'Median': 0.25, 'Sum': 1.1499999999999977}

# %%
result_list
# Out:
# [('baseline_nexp2_v1.7.1',
#   {'Mean': 240.59971428571427, 'Median': 242.306, 'Sum': 30315.564},
#   {'Mean': 0.03650793650793651, 'Median': 0.25, 'Sum': 4.6000000000000005}),
#  ('baseline_nexp2_v1.7',
#   {'Mean': 227.95896825396824, 'Median': 243.3515, 'Sum': 28722.829999999998},
#   {'Mean': 0.010753968253968257, 'Median': 0.25, 'Sum': 1.3550000000000004}),
#  ('footprint_6_v1.7.1',
#   {'Mean': 153.71603053435115, 'Median': 129.091, 'Sum': 20136.8},
#   {'Mean': -0.00992366412213741, 'Median': 0.25, 'Sum': -1.3000000000000007}),
#  ('rolling_fpw_scale0.2_nslice2_v1.7',
#   {'Mean': 184.9656587301587, 'Median': 142.21800000000002, 'Sum': 23305.673},
#   {'Mean': -0.13174603174603175, 'Median': 0.25, 'Sum': -16.6}),
#  ('rolling_fpw_scale0.2_nslice3_v1.7',
#   {'Mean': 175.91784920634922, 'Median': 145.50650000000002, 'Sum': 22165.649},
#   {'Mean': -0.09543650793650794, 'Median': 0.25, 'Sum': -12.025}),
#  ('rolling_fpw_scale0.4_nslice2_v1.7',
#   {'Mean': 183.89488095238093, 'Median': 154.708, 'Sum': 23170.754999999997},
#   {'Mean': -0.1242063492063492, 'Median': 0.25, 'Sum': -15.649999999999999}),
#  ('rolling_fpw_scale0.4_nslice3_v1.7',
#   {'Mean': 162.13380952380953, 'Median': 140.822, 'Sum': 20428.86},
#   {'Mean': -0.10654761904761906, 'Median': 0.25, 'Sum': -13.425}),
#  ('rolling_fpw_scale0.6_nslice2_v1.7',
#   {'Mean': 172.13835714285716, 'Median': 153.2615, 'Sum': 21689.433},
#   {'Mean': -0.11646825396825397, 'Median': 0.25, 'Sum': -14.675}),
#  ('rolling_fpw_scale0.6_nslice3_v1.7',
#   {'Mean': 147.9835238095238, 'Median': 154.888, 'Sum': 18645.924},
#   {'Mean': -0.08888888888888888, 'Median': 0.25, 'Sum': -11.2}),
#  ('rolling_fpw_scale0.8_nslice2_v1.7',
#   {'Mean': 164.33243650793654,
#    'Median': 150.36350000000002,
#    'Sum': 20705.887000000002},
#   {'Mean': -0.11646825396825396, 'Median': 0.25, 'Sum': -14.674999999999999}),
#  ('rolling_fpw_scale0.8_nslice3_v1.7',
#   {'Mean': 158.57289682539684, 'Median': 167.3475, 'Sum': 19980.185},
#   {'Mean': -0.11468253968253968, 'Median': 0.25, 'Sum': -14.45}),
#  ('rolling_fpw_scale0.9_nslice2_v1.7',
#   {'Mean': 171.69007142857143, 'Median': 170.8655, 'Sum': 21632.949},
#   {'Mean': -0.11884920634920634, 'Median': 0.225, 'Sum': -14.975}),
#  ('rolling_fpw_scale0.9_nslice3_v1.7',
#   {'Mean': 151.73303968253967, 'Median': 176.0805, 'Sum': 19118.362999999998},
#   {'Mean': -0.12658730158730155, 'Median': 0.225, 'Sum': -15.949999999999998}),
#  ('rolling_fpw_scale1.0_nslice2_v1.7',
#   {'Mean': 169.63716666666667, 'Median': 167.8025, 'Sum': 21374.283},
#   {'Mean': -0.1261904761904762, 'Median': 0.25, 'Sum': -15.9}),
#  ('rolling_fpw_scale1.0_nslice3_v1.7',
#   {'Mean': 159.69038888888886, 'Median': 179.2255, 'Sum': 20120.988999999998},
#   {'Mean': -0.08710317460317461, 'Median': 0.25, 'Sum': -10.975000000000001}),
#  ('six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7',
#   {'Mean': 298.34863358778625, 'Median': 251.381, 'Sum': 39083.671},
#   {'Mean': 0.008778625954198456, 'Median': 0.25, 'Sum': 1.1499999999999977})]

# %%
result_list # here's nside=8. The DDFs start to show up
# Out:
# [('baseline_nexp2_v1.7.1',
#   {'Mean': 60.71528290766209, 'Median': 58.196, 'Sum': 30904.079000000005},
#   {'Mean': 0.03837917485265226, 'Median': 0.25, 'Sum': 19.535000000000004})]

# %%
result_list # with no zlim_coeff set. hmmmm. nside=4
# Out:
# [('baseline_nexp2_v1.7.1',
#   {'Mean': 240.59971428571427, 'Median': 242.306, 'Sum': 30315.564},
#   {'Mean': 0.03650793650793651, 'Median': 0.25, 'Sum': 4.6000000000000005})]

# %%
result_list # when I had zlim_coeff=0.98
# Out:
# [('baseline_nexp2_v1.7.1',
#   {'Mean': 474.912992063492, 'Median': 457.24699999999996},
#   {'Mean': 0.08067063492063492, 'Median': 0.28300000000000003}),
#  ('baseline_nexp2_v1.7',
#   {'Mean': 450.8987698412698, 'Median': 442.27099999999996},
#   {'Mean': 0.050682539682539676, 'Median': 0.279}),
#  ('footprint_6_v1.7.1',
#   {'Mean': 285.8915648854962, 'Median': 201.20600000000002},
#   {'Mean': 0.025732824427480927, 'Median': 0.277}),
#  ('rolling_fpw_scale0.2_nslice2_v1.7',
#   {'Mean': 333.17418253968253, 'Median': 259.88599999999997},
#   {'Mean': -0.10682539682539682, 'Median': 0.2745}),
#  ('rolling_fpw_scale0.2_nslice3_v1.7',
#   {'Mean': 323.7800396825397, 'Median': 259.7805},
#   {'Mean': -0.06773412698412697, 'Median': 0.275}),
#  ('rolling_fpw_scale0.4_nslice2_v1.7',
#   {'Mean': 332.481373015873, 'Median': 293.03},
#   {'Mean': -0.09726190476190476, 'Median': 0.275}),
#  ('rolling_fpw_scale0.4_nslice3_v1.7',
#   {'Mean': 309.5222857142857, 'Median': 277.99800000000005},
#   {'Mean': -0.07627380952380951, 'Median': 0.275}),
#  ('rolling_fpw_scale0.6_nslice2_v1.7',
#   {'Mean': 329.24896825396826, 'Median': 281.4995},
#   {'Mean': -0.0870595238095238, 'Median': 0.275}),
#  ('rolling_fpw_scale0.6_nslice3_v1.7',
#   {'Mean': 310.7645079365079, 'Median': 333.18100000000004},
#   {'Mean': -0.05498015873015873, 'Median': 0.27525}),
#  ('rolling_fpw_scale0.8_nslice2_v1.7',
#   {'Mean': 325.04858730158725, 'Median': 310.1625},
#   {'Mean': -0.08364285714285713, 'Median': 0.276}),
#  ('rolling_fpw_scale0.8_nslice3_v1.7',
#   {'Mean': 310.1404285714285, 'Median': 366.626},
#   {'Mean': -0.0820357142857143, 'Median': 0.276}),
#  ('rolling_fpw_scale0.9_nslice2_v1.7',
#   {'Mean': 337.29934920634923, 'Median': 313.318},
#   {'Mean': -0.08532539682539682, 'Median': 0.275}),
#  ('rolling_fpw_scale0.9_nslice3_v1.7',
#   {'Mean': 316.22557142857147, 'Median': 380.84900000000005},
#   {'Mean': -0.0925, 'Median': 0.276}),
#  ('rolling_fpw_scale1.0_nslice2_v1.7',
#   {'Mean': 334.74623015873016, 'Median': 313.5085},
#   {'Mean': -0.08503174603174604, 'Median': 0.275}),
#  ('rolling_fpw_scale1.0_nslice3_v1.7',
#   {'Mean': 316.60480952380954, 'Median': 372.51300000000003},
#   {'Mean': -0.054511904761904754, 'Median': 0.276}),
#  ('six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7',
#   {'Mean': 662.7515419847327, 'Median': 761.25},
#   {'Mean': 0.06663740458015266, 'Median': 0.279})]
