# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
import sqlite3
import pandas as pd

# %%
data = np.load('SL_fbs15/baseline_v1.5_10yrs_SLTimeDelay/baseline_v1_5_10yrs_SNSLMetric_HEAL.npz')

# %%
temp = data['metricValues'] + 0
temp[data['mask']] = hp.UNSEEN
hp.mollview(temp)

# %%
con = sqlite3.connect('SL_fbs15/baseline_v1.5_10yrs_SLTimeDelay/resultsDb_sqlite.db')

# %%
summary = pd.read_sql('select * from summarystats;', con)
summary
# Out:
#    statId  metricId summaryName  summaryValue
# 0       1         1         Sum       8.67917
